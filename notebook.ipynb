# %%
print("Hello World")
# Out:
# Hello World

# %%
x = 2
if x >= 5:
    print("Hi guys")
else:
    print("Bye Guys")
# Out:
# Bye Guys

# %%
import math

# %%
math.sqrt(36)
# Out:
# 6.0

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.9/library/math
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
# ...

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.0.2'

# %%
import sys; import numpy as np
print("Python Path:", sys.executable)
print("NumPy Path:", np.__file__)
# Out:
# Python Path: /Users/sontudaniel/PyCharmMiscProject/.venv/bin/python
# NumPy Path: /Users/sontudaniel/PyCharmMiscProject/.venv/lib/python3.9/site-packages/numpy/__init__.py

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
list_1 = [1,2,3]
list_1
list_2 = [3,4,5]

# %%
list_1.extend(list_2)
list_1
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
list_2
# Out:
# [3, 4, 5]

# %%
print ("Hello Github Green Dots")
# Out:
# Hello Github Green Dots

# %%
import numpy as np

# %%
s = 5

# %%
s
# Out:
# 5

# %%
v = np.array([5,-2,4])

# %%
v
# Out:
# array([ 5, -2,  4])

# %%
m = np.array([[5,12,6],[-3,0,14]])

# %%
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
type(s)
# Out:
# int

# %%
type(v)
# Out:
# numpy.ndarray

# %%
s_array = np.array(5)

# %%
s_array
# Out:
# array(5)

# %%
type(s_array)
# Out:
# numpy.ndarray

# %%
m.shape
# Out:
# (2, 3)

# %%
v.shape
# Out:
# (3,)

# %%
v.reshape(1,3)
# Out:
# array([[ 5, -2,  4]])

# %%
v.reshape(3,1)
# Out:
# array([[ 5],
#        [-2],
#        [ 4]])

# %%
#Creating a tensor
m1=np.array([[5.2,12,6],[-3.8,0,14]])
m1
# Out:
# array([[ 5.2, 12. ,  6. ],
#        [-3.8,  0. , 14. ]])

# %%
m2=np.array([[9.5,8,7],[1.3,3,-5]])
m2
# Out:
# array([[ 9.5,  8. ,  7. ],
#        [ 1.3,  3. , -5. ]])

# %%
t = np.array([m1,m2])

# %%
t
# Out:
# array([[[ 5.2, 12. ,  6. ],
#         [-3.8,  0. , 14. ]],
#
#        [[ 9.5,  8. ,  7. ],
#         [ 1.3,  3. , -5. ]]])

# %%
t.shape
# Out:
# (2, 2, 3)

# %%
m1+m2
# Out:
# array([[14.7, 20. , 13. ],
#        [-2.5,  3. ,  9. ]])

# %%
m1-m2
# Out:
# array([[-4.3,  4. , -1. ],
#        [-5.1, -3. , 19. ]])

# %%
v1 = np.array([1,2,3,4,5,6])
v2 = np.array([6,5,4,3,2,1])

# %%
type(232)
# Out:
# int

# %% [markdown]
# Addition of vectors of different lenghts

# %%
v3 = np.array([1,2,3,4,5,6])
v3
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
v4 = np.array([1,2,3,4,5,7])
v4
# Out:
# array([1, 2, 3, 4, 5, 7])

# %%
v3+v4
# Out:
# array([ 2,  4,  6,  8, 10, 13])

# %% [markdown]
# Exceptions (additions of scalar+vectors)

# %%
1+v3
# Out:
# array([2, 3, 4, 5, 6, 7])

# %% [markdown]
# In such case, every element from the vector, was added +1

# %%
r4=np.array([[1,2,3,4,5,6],[1,2,3,4,5,6]])
r4
# Out:
# array([[1, 2, 3, 4, 5, 6],
#        [1, 2, 3, 4, 5, 6]])

# %%
10+r4
# Out:
# array([[11, 12, 13, 14, 15, 16],
#        [11, 12, 13, 14, 15, 16]])

# %% [markdown]
# Also exception was made here. Each element was added +10

# %% [markdown]
# Transposing Matrices

# %%
A = np.array([[5,12,5],[3,0,-14]])
A
# Out:
# array([[  5,  12,   5],
#        [  3,   0, -14]])

# %%
A.T
# Out:
# array([[  5,   3],
#        [ 12,   0],
#        [  5, -14]])

# %% [markdown]
# dDot Product

# %% [markdown]
# D

# %% [markdown]
# DOT PRODUCT

# %%
x=np.array([2,8,-4])
x
# Out:
# array([ 2,  8, -4])

# %%
y=np.array([1,-7,3])
y
# Out:
# array([ 1, -7,  3])

# %%
x*y
# Out:
# array([  2, -56, -12])

# %%
#wanted to get a clean response
print(np.dot(x,y))
# Out:
# -66

# %%
u=np.array([0,2,5,8])
v=np.array([20,3,4,-1])

# %%
print(np.dot(u,v))
# Out:
# 18
